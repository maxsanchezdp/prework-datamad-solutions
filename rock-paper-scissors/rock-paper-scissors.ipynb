# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
options=("stone","paper","scissors") #I prefer a tuple as it's inmutable and the order of the elements defines which beats which

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
max_games=5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
min_wins=int(max_games/2) + 1

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def machine():
  machine=random.choice(options)
  return machine

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def player():
  while True:
    try:
      player=str(input("\nEnter your choice (stone, paper or scissors): " ))
      assert (player in options)
      break
    except AssertionError:
      print ("\nInvalid choice!. Check for spaces and/or errors and try again.")
  return player

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def match(p,m):
  if p == options[options.index(m)+1-len(options)]:
    return 2 #human player wins
  elif p == options[options.index(m)-1]:
    return 1 #machine wins
  else:
    return 0 #tie 
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def status(p,m,pp,mp,t):
  print ("\nPlayer's choice: ", p)
  print ("Machine's choice: ", m)
  print ("Player's points: ", pp)
  print ("Machine's points: ", mp)
  print ("Ties: ", t)
    
# Create two variables that accumulate the wins of each participant
pp=0 #player's points
mp=0 #machine's points
t=0 #ties

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
for i in range(max_games):

  print("\nGame", str(i))

  p=player()
  m=machine()
  result=match(p,m)
  
  if result == 0:
    t+=1 #tie
  elif result == 2:
    pp+=1 #player wins match
  else:
    mp+=1 #machine wins match

  status(p,m,pp,mp,t)
  
  if (pp >= min_wins) | (mp >= min_wins):
    break

    
# Print by console the winner of the game based on who has more accumulated wins
print("\nEnd of the game...")  
if pp > mp:
    print("Player wins!")
elif mp > pp:
    print ("Machine wins!")
else:
    print("It's a tie!")
# Out:
# Game 0
#
# Enter your choice (stone, paper or scissors): stone
#
# Player's choice:  stone
# Machine's choice:  paper
# Player's points:  0
# Machine's points:  1
# Ties:  0
#
# Game 1
#
# Enter your choice (stone, paper or scissors): stone
#
# Player's choice:  stone
# Machine's choice:  scissors
# Player's points:  1
# Machine's points:  1
# Ties:  0
#
# Game 2
#
# Enter your choice (stone, paper or scissors): paper
#
# Player's choice:  paper
# Machine's choice:  paper
# Player's points:  1
# Machine's points:  1
# Ties:  1
#
# Game 3
#
# Enter your choice (stone, paper or scissors): scissors
#
# Player's choice:  scissors
# Machine's choice:  scissors
# Player's points:  1
# Machine's points:  1
# Ties:  2
#
# Game 4
#
# Enter your choice (stone, paper or scissors): paper
#
# Player's choice:  paper
# Machine's choice:  stone
# Player's points:  2
# Machine's points:  1
# Ties:  2
#
# End of the game...
# Player wins!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def max_games():
  while True:
    try:
      max_games=int(input("\nEnter the maximum number of games you wish to play (it needs to be an odd integer number): " ))
      assert (max_games%2 != 0) 
      break
    except AssertionError:
      print ("\nYour input is not an odd number. Try again.")
    except ValueError:
      print ("\nYour input is not an integer. Try again.")
  return max_games

# Assign a list of 5 possible options.
options=("spock","paper","lizzard","scissors","stone") #I prefer a tuple as it's inmutable and the order of the elements defines which beats which

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
max_games=max_games()


# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
min_wins=int(max_games/2) + 1

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def machine():
  machine=random.choice(options)
  return machine

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def player():
  while True:
    try:
      player=str(input("\nEnter your choice (spock, paper, lizzard, scissors or stone): " ))
      assert (player in options)
      break
    except AssertionError:
      print ("\nInvalid choice!. Check for spaces and/or errors and try again.")
  return player

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def match(p,m):
  if (p == options[options.index(m)+1-len(options)]) | (p == options[options.index(m)+2-len(options)]):
    return 2 #human player wins
  elif (p == options[options.index(m)-1]) | (p == options[options.index(m)-2]):
    return 1 #machine wins
  else:
    return 0 #tie

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def status(p,m,pp,mp,t):
  print ("\nPlayer's choice: ", p)
  print ("Machine's choice: ", m)
  print ("\nPlayer's points: ", pp)
  print ("Machine's points: ", mp)
  print ("Ties: ", t)
    
# Create two variables that accumulate the wins of each participant
pp=0 #player's points
mp=0 #machine's points
t=0 #ties


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
for i in range(max_games):

  print("\nGame", str(i))

  p=player()
  m=machine()
  result=match(p,m)
  
  if result == 0:
    t+=1 #tie
  elif result == 2:
    pp+=1 #player wins match
  else:
    mp+=1 #machine wins match

  status(p,m,pp,mp,t)
  
  if (pp >= min_wins) | (mp >= min_wins):
    break    
    
# Print by console the winner of the game based on who has more accumulated wins
print("\nEnd of the game...")  
if pp > mp:
    print("Player wins!")
elif mp > pp:
    print ("Machine wins!")
else:
    print("It's a tie!")
# Out:
# Enter the maximum number of games you wish to play (it needs to be an odd integer number): 10
#
# Your input is not an odd number. Try again.
#
# Enter the maximum number of games you wish to play (it needs to be an odd integer number): 11
#
# Game 0
#
# Enter your choice (spock, paper, lizzard, scissors or stone): LIZZA
#
# Invalid choice!. Check for spaces and/or errors and try again.
#
# Enter your choice (spock, paper, lizzard, scissors or stone): lizzard
#
# Player's choice:  lizzard
# Machine's choice:  paper
#
# Player's points:  1
# Machine's points:  0
# Ties:  0
#
# Game 1
#
# Enter your choice (spock, paper, lizzard, scissors or stone): spock
#
# Player's choice:  spock
# Machine's choice:  scissors
#
# Player's points:  2
# Machine's points:  0
# Ties:  0
#
# Game 2
#
# Enter your choice (spock, paper, lizzard, scissors or stone): paper
#
# Player's choice:  paper
# Machine's choice:  scissors
#
# Player's points:  2
# Machine's points:  1
# Ties:  0
#
# Game 3
#
# Enter your choice (spock, paper, lizzard, scissors or stone): stonee
#
# Invalid choice!. Check for spaces and/or errors and try again.
#
# Enter your choice (spock, paper, lizzard, scissors or stone): stone
#
# Player's choice:  stone
# Machine's choice:  spock
#
# Player's points:  2
# Machine's points:  2
# Ties:  0
#
# Game 4
#
# Enter your choice (spock, paper, lizzard, scissors or stone): stone
#
# Player's choice:  stone
# Machine's choice:  stone
#
# Player's points:  2
# Machine's points:  2
# Ties:  1
#
# Game 5
#
# Enter your choice (spock, paper, lizzard, scissors or stone): scissors
#
# Player's choice:  scissors
# Machine's choice:  scissors
#
# Player's points:  2
# Machine's points:  2
# Ties:  2
#
# Game 6
#
# Enter your choice (spock, paper, lizzard, scissors or stone): stone
#
# Player's choice:  stone
# Machine's choice:  lizzard
#
# Player's points:  3
# Machine's points:  2
# Ties:  2
#
# Game 7
#
# Enter your choice (spock, paper, lizzard, scissors or stone): lizzard
#
# Player's choice:  lizzard
# Machine's choice:  spock
#
# Player's points:  4
# Machine's points:  2
# Ties:  2
#
# Game 8
#
# Enter your choice (spock, paper, lizzard, scissors or stone): spock
#
# Player's choice:  spock
# Machine's choice:  stone
#
# Player's points:  5
# Machine's points:  2
# Ties:  2
#
# Game 9
#
# Enter your choice (spock, paper, lizzard, scissors or stone): spock
#
# Player's choice:  spock
# Machine's choice:  stone
#
# Player's points:  6
# Machine's points:  2
# Ties:  2
#
# End of the game...
# Player wins!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
